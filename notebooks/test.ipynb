# %%
import sys
import math
import numpy as np
import tensorflow as tf
import sonnet as snt

sys.path.append("../")

from crazycar.environments import Environment
from crazycar.agents import ImageAgent, SensorAgent
from crazycar.algos import TD3, SAC
from crazycar.encoder import Image, Sensor
from crazycar.utils import evaluation, initial
# Out:
# current_dir=c:\users\nutorbit\appdata\local\pypoetry\cache\virtualenvs\crazycar-domnw4dy-py3.7\lib\site-packages\pybullet_envs\bullet

# %%
class FLAGS:
    n_steps = int(1e6)
    start_steps = 1000
    step_update = 100
    batch_size = 256
    eval_steps = int(1e4)
    name = "test"

# %%
flags = FLAGS()

# %%
# initial necessary
initial()

# define environment
env = Environment(map_id=2)
agents = [ImageAgent, ImageAgent]
positions = [[2.4, 1, math.pi / 2], [2.7, 4, math.pi / 2]]

for agent, pos in zip(agents, positions):
    env.insert_car(agent, pos)
# Out:
# WARNING:tensorflow:From d:\workspace\crazycar\crazycar\utils.py:69: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# options=

# %%
# while True:
#     env.step(np.array([[0, 0], [0, 0]]))

# %%
# define models
models = [SAC(Image, 1), SAC(Image, 1)]
writers = [
    tf.summary.create_file_writer(f'./logs/{FLAGS.name}/{model.__class__.__name__}-{idx}')
    for idx, model in enumerate(models)
]

# %%
print(snt.format_variables(models[0].variables))
# Out:
# | Variable                                                            | Spec           | Trainable   | Device   |
# |---------------------------------------------------------------------+----------------+-------------+----------|
# | SAC/log_alpha                                                       | f32[]          | True        | GPU      |
# | SAC/actor/image/impala_cnn/dense/kernel                             | f32[288,256]   | True        | GPU      |
# | SAC/actor/image/impala_cnn/dense/bias                               | f32[256]       | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_1/kernel          | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_1/bias            | f32[16]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_11/kernel         | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_11/bias           | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_12/kernel         | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_12/bias           | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_13/kernel         | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_13/bias           | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_14/kernel         | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_14/bias           | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_2/kernel          | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_2/bias            | f32[16]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_3/kernel          | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_3/bias            | f32[16]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_4/kernel          | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_4/bias            | f32[16]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_6/kernel          | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_6/bias            | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_7/kernel          | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_7/bias            | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_8/kernel          | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_8/bias            | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_9/kernel          | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/impala_residual/conv2d_9/bias            | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/sequential/conv2d/kernel                 | f32[3,3,1,16]  | True        | GPU      |
# | SAC/actor/image/impala_cnn/sequential/conv2d/bias                   | f32[16]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/sequential/conv2d_10/kernel              | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/sequential/conv2d_10/bias                | f32[32]        | True        | GPU      |
# | SAC/actor/image/impala_cnn/sequential/conv2d_5/kernel               | f32[3,3,16,32] | True        | GPU      |
# | SAC/actor/image/impala_cnn/sequential/conv2d_5/bias                 | f32[32]        | True        | GPU      |
# | SAC/actor/linear/w                                                  | f32[256,256]   | True        | GPU      |
# | SAC/actor/linear/w                                                  | f32[256,1]     | True        | GPU      |
# | SAC/actor/linear/w                                                  | f32[256,1]     | True        | GPU      |
# | SAC/actor/linear/b                                                  | f32[256]       | True        | GPU      |
# | SAC/actor/linear/b                                                  | f32[1]         | True        | GPU      |
# | SAC/actor/linear/b                                                  | f32[1]         | True        | GPU      |
# | SAC/actor_optimizer/t                                               | i64[]          | False       | GPU      |
# | SAC/actor_target/image/impala_cnn/dense_1/kernel                    | f32[288,256]   | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/dense_1/bias                      | f32[256]       | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_16/kernel  | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_16/bias    | f32[16]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_17/kernel  | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_17/bias    | f32[16]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_18/kernel  | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_18/bias    | f32[16]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_19/kernel  | f32[3,3,16,16] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_19/bias    | f32[16]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_21/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_21/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_22/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_22/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_23/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_23/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_24/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_24/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_26/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_26/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_27/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_27/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_28/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_28/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_29/kernel  | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/impala_residual/conv2d_29/bias    | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/sequential/conv2d_15/kernel       | f32[3,3,1,16]  | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/sequential/conv2d_15/bias         | f32[16]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/sequential/conv2d_20/kernel       | f32[3,3,16,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/sequential/conv2d_20/bias         | f32[32]        | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/sequential/conv2d_25/kernel       | f32[3,3,32,32] | True        | GPU      |
# | SAC/actor_target/image/impala_cnn/sequential/conv2d_25/bias         | f32[32]        | True        | GPU      |
# | SAC/actor_target/linear/w                                           | f32[256,256]   | True        | GPU      |
# | SAC/actor_target/linear/w                                           | f32[256,1]     | True        | GPU      |
# | SAC/actor_target/linear/w                                           | f32[256,1]     | True        | GPU      |
# | SAC/actor_target/linear/b                                           | f32[256]       | True        | GPU      |
# | SAC/actor_target/linear/b                                           | f32[1]         | True        | GPU      |
# | SAC/actor_target/linear/b                                           | f32[1]         | True        | GPU      |
# | SAC/alpha_optimizer/t                                               | i64[]          | False       | GPU      |
# | SAC/critic/image/impala_cnn/dense_2/kernel                          | f32[288,256]   | True        | GPU      |
# | SAC/critic/image/impala_cnn/dense_2/bias                            | f32[256]       | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_31/kernel        | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_31/bias          | f32[16]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_32/kernel        | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_32/bias          | f32[16]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_33/kernel        | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_33/bias          | f32[16]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_34/kernel        | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_34/bias          | f32[16]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_36/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_36/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_37/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_37/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_38/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_38/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_39/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_39/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_41/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_41/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_42/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_42/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_43/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_43/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_44/kernel        | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/impala_residual/conv2d_44/bias          | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/sequential/conv2d_30/kernel             | f32[3,3,1,16]  | True        | GPU      |
# | SAC/critic/image/impala_cnn/sequential/conv2d_30/bias               | f32[16]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/sequential/conv2d_35/kernel             | f32[3,3,16,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/sequential/conv2d_35/bias               | f32[32]        | True        | GPU      |
# | SAC/critic/image/impala_cnn/sequential/conv2d_40/kernel             | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic/image/impala_cnn/sequential/conv2d_40/bias               | f32[32]        | True        | GPU      |
# | SAC/critic/linear/w                                                 | f32[257,256]   | True        | GPU      |
# | SAC/critic/linear/w                                                 | f32[256,1]     | True        | GPU      |
# | SAC/critic/linear/w                                                 | f32[257,256]   | True        | GPU      |
# | SAC/critic/linear/w                                                 | f32[256,1]     | True        | GPU      |
# | SAC/critic/linear/b                                                 | f32[256]       | True        | GPU      |
# | SAC/critic/linear/b                                                 | f32[1]         | True        | GPU      |
# | SAC/critic/linear/b                                                 | f32[256]       | True        | GPU      |
# | SAC/critic/linear/b                                                 | f32[1]         | True        | GPU      |
# | SAC/critic_optimizer/t                                              | i64[]          | False       | GPU      |
# | SAC/critic_target/image/impala_cnn/dense_3/kernel                   | f32[288,256]   | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/dense_3/bias                     | f32[256]       | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_46/kernel | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_46/bias   | f32[16]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_47/kernel | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_47/bias   | f32[16]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_48/kernel | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_48/bias   | f32[16]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_49/kernel | f32[3,3,16,16] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_49/bias   | f32[16]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_51/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_51/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_52/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_52/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_53/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_53/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_54/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_54/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_56/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_56/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_57/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_57/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_58/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_58/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_59/kernel | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/impala_residual/conv2d_59/bias   | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/sequential/conv2d_45/kernel      | f32[3,3,1,16]  | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/sequential/conv2d_45/bias        | f32[16]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/sequential/conv2d_50/kernel      | f32[3,3,16,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/sequential/conv2d_50/bias        | f32[32]        | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/sequential/conv2d_55/kernel      | f32[3,3,32,32] | True        | GPU      |
# | SAC/critic_target/image/impala_cnn/sequential/conv2d_55/bias        | f32[32]        | True        | GPU      |
# | SAC/critic_target/linear/w                                          | f32[257,256]   | True        | GPU      |
# | SAC/critic_target/linear/w                                          | f32[256,1]     | True        | GPU      |
# | SAC/critic_target/linear/w                                          | f32[257,256]   | True        | GPU      |
# | SAC/critic_target/linear/w                                          | f32[256,1]     | True        | GPU      |
# | SAC/critic_target/linear/b                                          | f32[256]       | True        | GPU      |
# | SAC/critic_target/linear/b                                          | f32[1]         | True        | GPU      |
# | SAC/critic_target/linear/b                                          | f32[256]       | True        | GPU      |
# | SAC/critic_target/linear/b                                          | f32[1]         | True        | GPU      |

# %%
step = 0
max_rew = [float("-inf") for _ in range(len(models))]

while step < FLAGS.n_steps:
    obs = env.reset()
    done = False

    while not done:

        # get action
        acts = []
        for idx in range(len(models)):
            if step > FLAGS.start_steps:
                acts.append(models[idx].predict(obs[idx]))
            else:
                acts.append(models[idx].random_action())
        acts = np.squeeze(np.array(acts), axis=1)

        # apply action
        next_obs, rew, done, info = env.step(acts)

        # save replay
        for idx in range(len(models)):
            models[idx].rb.store({
                "obs": obs[idx],
                "act": acts[idx],
                "next_obs": next_obs[idx],
                "rew": rew[idx],
                "done": done
            })

        # update params
        if step > FLAGS.batch_size and step % FLAGS.step_update == 0:
            for _ in range(FLAGS.step_update):
                for idx, model in enumerate(models):
                    metric = model.update_params(step, FLAGS.batch_size)

                    # write tensorboard
                    with writers[idx].as_default():
                        model.write_metric(metric, step)

        # evaluation
        if step % FLAGS.eval_steps == 0:
            mean_rew, mean_step = evaluation(env, models)
            print(f"|Evaluation at {step:08d}| Mean reward: {str(mean_rew)}, Mean step: {str(mean_step)}")

            for idx, model in enumerate(models):

                # save model
                if mean_rew[idx] > max_rew[idx]:
                    # tf.saved_model.save(model.actor, f"./models/{FLAGS.name}/{model.__class__.__name__}-{idx}")
                    max_rew[idx] = mean_rew[idx]

                # addition metric
                with writers[idx].as_default():
                    tf.summary.scalar("track/mean_reward", mean_rew[idx], step)
                    tf.summary.scalar("track/mean_step", mean_step, step)

        # to next state
        step += 1
        done = done[0]
        obs = next_obs

# %%
def main(_):

    # initial necessary
    initial()

    # define environment
    env = Environment(map_id=2)
    agents = [SensorAgent, SensorAgent]
    positions = [[2.4, 1, math.pi / 2], [2.7, 4, math.pi / 2]]
    # positions = [[2.5, 6, math.pi * 2 / 2]]
    for agent, pos in zip(agents, positions):
        env.insert_car(agent, pos)

    # define models
    models = [SAC(Sensor, 1), SAC(Sensor, 1)]
    writers = [
        tf.summary.create_file_writer(f'./logs/{FLAGS.name}/{model.__class__.__name__}-{idx}')
        for idx, model in enumerate(models)
    ]

    step = 0
    max_rew = [float("-inf") for _ in range(len(models))]

    while step < FLAGS.n_steps:
        obs = env.reset()
        done = False

        while not done:

            # get action
            acts = []
            for idx in range(len(models)):
                if step > FLAGS.start_steps:
                    acts.append(models[idx].predict(obs[idx]))
                else:
                    acts.append(models[idx].random_action())
            acts = np.squeeze(np.array(acts), axis=1)

            # apply action
            next_obs, rew, done, info = env.step(acts)

            # save replay
            for idx in range(len(models)):
                models[idx].rb.store({
                    "obs": obs[idx],
                    "act": acts[idx],
                    "next_obs": next_obs[idx],
                    "rew": rew[idx],
                    "done": done
                })

            # update params
            if step > FLAGS.batch_size and step % FLAGS.step_update == 0:
                for _ in range(FLAGS.step_update):
                    for idx, model in enumerate(models):
                        metric = model.update_params(step, FLAGS.batch_size)

                        # write tensorboard
                        with writers[idx].as_default():
                            model.write_metric(metric, step)

            # evaluation
            if step % FLAGS.eval_steps == 0:
                mean_rew, mean_step = evaluation(env, models)
                print(f"|Evaluation at {step:08d}| Mean reward: {str(mean_rew)}, Mean step: {str(mean_step)}")

                for idx, model in enumerate(models):

                    # save model
                    if mean_rew[idx] > max_rew[idx]:
                        # tf.saved_model.save(model.actor, f"./models/{FLAGS.name}/{model.__class__.__name__}-{idx}")
                        max_rew[idx] = mean_rew[idx]

                    # addition metric
                    with writers[idx].as_default():
                        tf.summary.scalar("track/mean_reward", mean_rew[idx], step)
                        tf.summary.scalar("track/mean_step", mean_step, step)

            # to next state
            step += 1
            done = done[0]
            obs = next_obs


if __name__ == "__main__":
    app.run(main)
